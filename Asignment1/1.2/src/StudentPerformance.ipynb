# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/sreekar/Desktop/Asignment1/1.2/rawdata/StudentsPerformance.csv')

# %%
data.to_csv('/Users/sreekar/Desktop/Asignment1/1.2/cleandata//clean_data.csv')

# %%
data.to_csv ('/Users/sreekar/Desktop/Asignment1/1.2/cleandata/processed data.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['Total_Score'] = data['math score'] + data['writing score'] + data['reading score']

# %%
data['average'] = data['Total_Score']/3

# %%
display(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      Total_Score    average
# 0            218  72.666667
# 1            247  82.333333
# 2            278  92.666667
# 3            148  49.333333
# 4            229  76.333333
# ..           ...        ...
# 995          282  94.000000
# 996          172  57.333333
# 997          195  65.000000
# 998          223  74.333333
# 999          249  83.000000
#
# [1000 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
# visualization 1: Bar plot of gender distribution
gender_counts = data['gender'].value_counts()
plt.bar(gender_counts.index, gender_counts.values)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.savefig ('/Users/sreekar/Desktop/Asignment1/1.2/results//Gender_distribution.png')
plt.show()

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: scipy>=1.0 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: packaging>=20.0 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
# visualization 2: Box plot of math scores by gender
sns.boxplot(x='gender', y='average', data=data)
plt.title('Average by Gender')
plt.savefig ('/Users/sreekar/Desktop/Asignment1/1.2/results//Math_Scores_by_Gender.png')
plt.show()

# %%
data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
parentgraph= sns.barplot(data = data, x = 'parental level of education', y= 'average', hue = 'parental level of education')
fig_parent= parentgraph.get_figure()
fig_parent.savefig("/Users/sreekar/Desktop/Asignment1/1.2/results/parentimage.jpeg")

#masters degree has better avg score

# %%
# visualization 4: Density plot of writing scores by lunch type
sns.kdeplot(x='reading score', data=data, hue='lunch', fill=True, alpha=.3)
plt.title('Reading Scores by Lunch Type')
plt.xlabel('Reading Score')
plt.savefig ('/Users/sreekar/Desktop/Asignment1/1.2/results//Reading_Scores_by_Lunch_Type.png')
plt.show()

# %%
data['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
#find the count
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
graph_test_prep=sns.swarmplot(x ='test preparation course', y= 'average', data = data)
fig_testprep=graph_test_prep.get_figure()
fig_testprep.savefig("/Users/sreekar/Desktop/Asignment1/1.2/results/testprep01image.jpeg")
# Out:
# /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 9.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# visualization 5: Heatmap of correlation matrix
corr= data.corr(numeric_only=True)
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.title('Correlation Matrix')
plt.savefig ('/Users/sreekar/Desktop/Asignment1/1.2/results//Correlation_Matrix.png')
plt.show()

# %%
pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (1.4.4)
# Collecting pandas
#   Downloading pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 42.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/sreekar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# Successfully installed pandas-1.5.3
# Note: you may need to restart the kernel to use updated packages.
